# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Beno\Desktop\Lab0_data.csv')

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
import numpy
import matplotlib.pyplot as plt

# %%
plt.plot(df["time_sec"], df["VehicleSpeed_mph"], color='red')
plt.ylabel("Vehicle Speed [mph]")
plt.xlabel("Time [seconds]")
plt.title("Vehicle Speed vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["EngineSpeed_rpm"], color='blue')
plt.ylabel("Engine Speed [rpm]")
plt.xlabel("Time [seconds]")
plt.title("Engine Speed vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["EngineTorque"], color='purple')
plt.ylabel("Engine Torque [lb-ft]")
plt.xlabel("Time [seconds]")
plt.title("Engine Torque vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["AccelPedalPos"], color='green')
plt.ylabel("Accelerator Pedal Position [degrees]")
plt.xlabel("Time [seconds]")
plt.title("Accelerator Pedal Position vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["BrakePedalPos"], color='orange')
plt.ylabel("Brake Pedal Position [degrees]")
plt.xlabel("Time [seconds]")
plt.title("Brake Pedal Position vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["TurnSignal"], color='yellow')
plt.ylabel("Turn Signal Operation [On/Off State]")
plt.xlabel("Time [seconds]")
plt.title("Turn Signal Operation vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["TurnSignal"], color='brown')
plt.ylabel("Turn Signal Operation [On/Off State]")
plt.xlabel("Time [seconds]")
plt.title("Turn Signal Operation vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["Latitude_deg"], color='silver')
plt.ylabel("Latitude [degrees]")
plt.xlabel("Time [seconds]")
plt.title("Latitude vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["Longitude_deg"], color='maroon')
plt.ylabel("Longitude [degrees]")
plt.xlabel("Time [seconds]")
plt.title("Longitude vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["Altitude"], color='maroon')
plt.ylabel("Altitude [feet]")
plt.xlabel("Time [seconds]")
plt.title("Altitude vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["Distance"], color='black')
plt.ylabel("Distance [feet]")
plt.xlabel("Time [seconds]")
plt.title("Distance vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["SteerAngle"], color='red')
plt.ylabel("Steering Angle [degrees]")
plt.xlabel("Time [seconds]")
plt.title("Steering Angle vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["TransmissionGear"], color='blue')
plt.ylabel("Transmission Gear [gear]")
plt.xlabel("Time [seconds]")
plt.title("Transmission Gear vs Time")
plt.grid()

# %%
plt.plot(df["time_sec"], df["TransmissionGear"], color='green')
plt.ylabel("Transmission Gear [gear]")
plt.xlabel("Time [seconds]")
plt.title("Transmission Gear vs Time")
plt.grid()
