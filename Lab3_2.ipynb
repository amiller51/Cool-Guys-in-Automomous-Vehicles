# %%
# Import required packages:
import cv2
import numpy as np
from matplotlib import pyplot as plt


def show_img_with_matplotlib(color_img, title, pos):
    """Shows an image using matplotlib capabilities"""

    img_RGB = color_img[:, :, ::-1]

    ax = plt.subplot(1, 1, pos)
    plt.imshow(img_RGB)
    plt.title(title)
    plt.axis('off')


# load the COCO class labels:
class_names = open("coco.names").read().strip().split("\n")

# Load the serialized caffe model from disk:
net = cv2.dnn.readNetFromDarknet("yolov3.cfg", "yolov3.weights")

# Load input image:
#image = cv2.imread("object_detection_test_image.png")

# Setup video file writer



def process(image):
    (H, W) = image.shape[:2]

    # Get the output layer names:
    layer_names = net.getLayerNames()
    layer_names = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # Create the blob with a size of (416, 416), swap red and blue channels
    # and also a scale factor of 1/255 = 0,003921568627451:
    blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416), swapRB=True, crop=False)
    print(blob.shape)

    # Feed the input blob to the network, perform inference and get the output:
    net.setInput(blob)
    layerOutputs = net.forward(layer_names)

    # Get inference time:
    t, _ = net.getPerfProfile()
    print('Inference time: %.2f ms' % (t * 1000.0 / cv2.getTickFrequency()))

    # Initialization:
    boxes = []
    confidences = []
    class_ids = []

    # loop over each of the layer outputs
    for output in layerOutputs:
        # loop over each of the detections
        for detection in output:
            # Get class ID and confidence of the current detection:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            # Filter out weak predictions:
            if confidence > 0.25:
                # Scale the bounding box coordinates (center, width, height) using the dimensions of the original image:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY, width, height) = box.astype("int")

                # Calculate the top-left corner of the bounding box:
                x = int(centerX - (width / 2))
                y = int(centerY - (height / 2))

                # Update the information we have for each detection:
                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    # We can apply non-maxima suppression (eliminate weak and overlapping bounding boxes):
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.3)

    # Show the results (if any object is detected after non-maxima suppression):
    if len(indices) > 0:
        for i in indices.flatten():
            # Extract the (previously recalculated) bounding box coordinates:
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            # Draw label and confidence:
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
            label = "{}: {:.4f}".format(class_names[class_ids[i]], confidences[i])
            labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)
            y = max(y, labelSize[1])
            cv2.rectangle(image, (x, y - labelSize[1]), (x + labelSize[0], y + 0), (0, 255, 0), cv2.FILLED)
            cv2.putText(image, label, (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)
    return image
    # Create the dimensions of the figure and set title:
    #fig = plt.figure(figsize=(14, 8))
    #plt.suptitle("Object detection using OpenCV DNN module and YOLO V3", fontsize=14, fontweight='bold')
    #fig.patch.set_facecolor('silver')

    # Show the output image
    #show_img_with_matplotlib(image, "YOLO V3 for object detection", 1)

    # Show the Figure:
    #plt.show()
    
#process(image)

# %%
# Detect lane lines from road through captured video - Hunter
cap = cv2.VideoCapture('video_edit.mp4')

# Get height & width of camera frames
width= int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height= int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
writer = cv2.VideoWriter('objectdetvideo.avi', cv2.VideoWriter_fourcc(*'MJPG'), 20, (width,height))

while cap.isOpened():
    ret, frame = cap.read()
    frame = process(frame)
    writer.write(frame)
    cv2.imshow('Object Detection Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# (1, 3, 416, 416)
# Inference time: 723.57 ms
# (1, 3, 416, 416)
# Inference time: 819.99 ms
# (1, 3, 416, 416)
# Inference time: 775.73 ms
# (1, 3, 416, 416)
# Inference time: 682.66 ms
# (1, 3, 416, 416)
# Inference time: 598.31 ms
# (1, 3, 416, 416)
# Inference time: 632.94 ms
# (1, 3, 416, 416)
# Inference time: 632.78 ms
# (1, 3, 416, 416)
# Inference time: 594.63 ms
# (1, 3, 416, 416)
# Inference time: 603.08 ms
# (1, 3, 416, 416)
# Inference time: 615.18 ms
# (1, 3, 416, 416)
# Inference time: 670.23 ms
# (1, 3, 416, 416)
# Inference time: 735.71 ms
# (1, 3, 416, 416)
# Inference time: 602.62 ms
# (1, 3, 416, 416)
# Inference time: 608.88 ms
# (1, 3, 416, 416)
# Inference time: 613.88 ms
# (1, 3, 416, 416)
# Inference time: 801.91 ms
# (1, 3, 416, 416)
# Inference time: 619.36 ms
# (1, 3, 416, 416)
# Inference time: 629.37 ms
# (1, 3, 416, 416)
# Inference time: 626.43 ms
# (1, 3, 416, 416)
# Inference time: 632.33 ms
# (1, 3, 416, 416)
# Inference time: 630.74 ms
# (1, 3, 416, 416)
# Inference time: 662.63 ms
# (1, 3, 416, 416)
# Inference time: 644.21 ms
# (1, 3, 416, 416)
# Inference time: 644.63 ms
# (1, 3, 416, 416)
# Inference time: 650.70 ms
# (1, 3, 416, 416)
# Inference time: 724.06 ms
# (1, 3, 416, 416)
# Inference time: 891.38 ms
# (1, 3, 416, 416)
# Inference time: 694.40 ms
# (1, 3, 416, 416)
# Inference time: 675.52 ms
# (1, 3, 416, 416)
# Inference time: 805.50 ms
# (1, 3, 416, 416)
# Inference time: 796.28 ms
# (1, 3, 416, 416)
# Inference time: 878.36 ms
# (1, 3, 416, 416)
# Inference time: 720.79 ms
# (1, 3, 416, 416)
# Inference time: 676.12 ms
# (1, 3, 416, 416)
# Inference time: 680.85 ms
# (1, 3, 416, 416)
# Inference time: 707.96 ms
# (1, 3, 416, 416)
# Inference time: 732.56 ms
# (1, 3, 416, 416)
# Inference time: 679.10 ms
# (1, 3, 416, 416)
# Inference time: 676.90 ms
# (1, 3, 416, 416)
# Inference time: 674.64 ms
# (1, 3, 416, 416)
# Inference time: 672.91 ms
# (1, 3, 416, 416)
# Inference time: 675.60 ms
# (1, 3, 416, 416)
# Inference time: 697.09 ms
# (1, 3, 416, 416)
# Inference time: 672.73 ms
# (1, 3, 416, 416)
# Inference time: 685.56 ms
# (1, 3, 416, 416)
# Inference time: 769.65 ms
# (1, 3, 416, 416)
# Inference time: 677.56 ms
# (1, 3, 416, 416)
# Inference time: 672.60 ms
# (1, 3, 416, 416)
# Inference time: 673.95 ms
# (1, 3, 416, 416)
# Inference time: 676.45 ms
# (1, 3, 416, 416)
# Inference time: 683.54 ms
# (1, 3, 416, 416)
# Inference time: 856.61 ms
# (1, 3, 416, 416)
# Inference time: 678.30 ms
# (1, 3, 416, 416)
# Inference time: 690.05 ms
# (1, 3, 416, 416)
# Inference time: 673.86 ms
# (1, 3, 416, 416)
# Inference time: 669.23 ms
# (1, 3, 416, 416)
# Inference time: 722.44 ms
# (1, 3, 416, 416)
# Inference time: 797.52 ms
# (1, 3, 416, 416)
# Inference time: 794.57 ms
# (1, 3, 416, 416)
# Inference time: 692.12 ms
# (1, 3, 416, 416)
# Inference time: 686.60 ms
# (1, 3, 416, 416)
# Inference time: 941.53 ms
# (1, 3, 416, 416)
# Inference time: 980.56 ms
# (1, 3, 416, 416)
# Inference time: 699.61 ms
# (1, 3, 416, 416)
# Inference time: 682.07 ms
# (1, 3, 416, 416)
# Inference time: 686.92 ms
# (1, 3, 416, 416)
# Inference time: 677.31 ms
# (1, 3, 416, 416)
# Inference time: 676.58 ms
# (1, 3, 416, 416)
# Inference time: 679.65 ms
# (1, 3, 416, 416)
# Inference time: 749.73 ms
# (1, 3, 416, 416)
# Inference time: 872.10 ms
# (1, 3, 416, 416)
# Inference time: 686.45 ms
# (1, 3, 416, 416)
# Inference time: 676.25 ms
# (1, 3, 416, 416)
# Inference time: 676.93 ms
# (1, 3, 416, 416)
# Inference time: 705.69 ms
# (1, 3, 416, 416)
# Inference time: 708.83 ms
# (1, 3, 416, 416)
# Inference time: 670.73 ms
# (1, 3, 416, 416)
# Inference time: 678.83 ms
# (1, 3, 416, 416)
# Inference time: 710.94 ms
# (1, 3, 416, 416)
# Inference time: 669.88 ms
# (1, 3, 416, 416)
# Inference time: 674.38 ms
# (1, 3, 416, 416)
# Inference time: 672.31 ms
# (1, 3, 416, 416)
# Inference time: 825.97 ms
# (1, 3, 416, 416)
# Inference time: 851.09 ms
# (1, 3, 416, 416)
# Inference time: 750.69 ms
# (1, 3, 416, 416)
# Inference time: 677.41 ms
# (1, 3, 416, 416)
# Inference time: 674.28 ms
# (1, 3, 416, 416)
# Inference time: 670.08 ms
# (1, 3, 416, 416)
# Inference time: 675.13 ms
# (1, 3, 416, 416)
# Inference time: 705.58 ms
# (1, 3, 416, 416)
# Inference time: 846.61 ms
# (1, 3, 416, 416)
# Inference time: 720.64 ms
# (1, 3, 416, 416)
# Inference time: 697.26 ms
# (1, 3, 416, 416)
# Inference time: 813.61 ms
# (1, 3, 416, 416)
# Inference time: 880.82 ms
# (1, 3, 416, 416)
# Inference time: 771.22 ms
# (1, 3, 416, 416)
# Inference time: 811.95 ms
# (1, 3, 416, 416)
# Inference time: 684.49 ms
# (1, 3, 416, 416)
# Inference time: 675.76 ms
# (1, 3, 416, 416)
# Inference time: 675.89 ms
# (1, 3, 416, 416)
# Inference time: 668.45 ms
# (1, 3, 416, 416)
# Inference time: 719.15 ms
# (1, 3, 416, 416)
# Inference time: 692.76 ms
# (1, 3, 416, 416)
# Inference time: 664.14 ms
# (1, 3, 416, 416)
# Inference time: 666.04 ms
# (1, 3, 416, 416)
# Inference time: 689.65 ms
# (1, 3, 416, 416)
# Inference time: 690.62 ms
# (1, 3, 416, 416)
# Inference time: 700.86 ms
# (1, 3, 416, 416)
# Inference time: 677.66 ms
# (1, 3, 416, 416)
# Inference time: 804.65 ms
# (1, 3, 416, 416)
# Inference time: 749.26 ms
# (1, 3, 416, 416)
# Inference time: 692.05 ms
# (1, 3, 416, 416)
# Inference time: 667.57 ms
# (1, 3, 416, 416)
# Inference time: 688.45 ms
# (1, 3, 416, 416)
# Inference time: 860.94 ms
# (1, 3, 416, 416)
# Inference time: 689.90 ms
# (1, 3, 416, 416)
# Inference time: 802.62 ms
# (1, 3, 416, 416)
# Inference time: 730.55 ms
# (1, 3, 416, 416)
# Inference time: 673.58 ms
# (1, 3, 416, 416)
# Inference time: 693.55 ms
# (1, 3, 416, 416)
# Inference time: 672.21 ms
# (1, 3, 416, 416)
# Inference time: 662.46 ms
# (1, 3, 416, 416)
# Inference time: 817.28 ms
# (1, 3, 416, 416)
# Inference time: 661.05 ms
# (1, 3, 416, 416)
# Inference time: 669.41 ms
# (1, 3, 416, 416)
# Inference time: 679.08 ms
# (1, 3, 416, 416)
# Inference time: 657.54 ms
# (1, 3, 416, 416)
# Inference time: 654.07 ms
# (1, 3, 416, 416)
# Inference time: 738.95 ms
# (1, 3, 416, 416)
# Inference time: 880.20 ms
# (1, 3, 416, 416)
# Inference time: 807.79 ms
# (1, 3, 416, 416)
# Inference time: 754.78 ms
# (1, 3, 416, 416)
# Inference time: 751.45 ms
# (1, 3, 416, 416)
# Inference time: 749.79 ms
# (1, 3, 416, 416)
# Inference time: 780.55 ms
# (1, 3, 416, 416)
# Inference time: 760.26 ms
# (1, 3, 416, 416)
# Inference time: 735.28 ms
# (1, 3, 416, 416)
# Inference time: 949.02 ms
# (1, 3, 416, 416)
# Inference time: 676.25 ms
# (1, 3, 416, 416)
# Inference time: 663.14 ms
# (1, 3, 416, 416)
# Inference time: 661.43 ms
# (1, 3, 416, 416)
# Inference time: 663.87 ms
# (1, 3, 416, 416)
# Inference time: 668.44 ms
# (1, 3, 416, 416)
# Inference time: 656.77 ms
# (1, 3, 416, 416)
# Inference time: 668.29 ms
# (1, 3, 416, 416)
# Inference time: 657.32 ms
# (1, 3, 416, 416)
# Inference time: 642.16 ms
# (1, 3, 416, 416)
# Inference time: 650.94 ms
# (1, 3, 416, 416)
# Inference time: 817.04 ms
# (1, 3, 416, 416)
# Inference time: 657.77 ms
# (1, 3, 416, 416)
# Inference time: 655.32 ms
# (1, 3, 416, 416)
# Inference time: 648.09 ms
# (1, 3, 416, 416)
# Inference time: 640.03 ms
# (1, 3, 416, 416)
# Inference time: 693.74 ms
# (1, 3, 416, 416)
# Inference time: 641.04 ms
# (1, 3, 416, 416)
# Inference time: 653.36 ms
# (1, 3, 416, 416)
# Inference time: 646.42 ms
# (1, 3, 416, 416)
# Inference time: 661.36 ms
# (1, 3, 416, 416)
# Inference time: 658.02 ms
# (1, 3, 416, 416)
# Inference time: 638.44 ms
# (1, 3, 416, 416)
# Inference time: 638.98 ms
# (1, 3, 416, 416)
# Inference time: 643.01 ms
# (1, 3, 416, 416)
# Inference time: 635.32 ms
# (1, 3, 416, 416)
# Inference time: 638.82 ms
# (1, 3, 416, 416)
# Inference time: 656.19 ms
# (1, 3, 416, 416)
# Inference time: 670.49 ms
# (1, 3, 416, 416)
# Inference time: 646.01 ms
# (1, 3, 416, 416)
# Inference time: 643.07 ms
# (1, 3, 416, 416)
# Inference time: 640.83 ms
# (1, 3, 416, 416)
# Inference time: 804.54 ms
# (1, 3, 416, 416)
# Inference time: 645.53 ms
# (1, 3, 416, 416)
# Inference time: 651.36 ms
# (1, 3, 416, 416)
# Inference time: 704.60 ms
# (1, 3, 416, 416)
# Inference time: 670.51 ms
# (1, 3, 416, 416)
# Inference time: 637.78 ms
# (1, 3, 416, 416)
# Inference time: 783.09 ms
# (1, 3, 416, 416)
# Inference time: 640.75 ms
# (1, 3, 416, 416)
# Inference time: 658.42 ms
# (1, 3, 416, 416)
# Inference time: 663.72 ms
# (1, 3, 416, 416)
# Inference time: 642.14 ms
# (1, 3, 416, 416)
# Inference time: 715.33 ms
# (1, 3, 416, 416)
# Inference time: 699.31 ms
# (1, 3, 416, 416)
# Inference time: 673.60 ms
# (1, 3, 416, 416)
# Inference time: 662.93 ms
# (1, 3, 416, 416)
# Inference time: 680.41 ms
# (1, 3, 416, 416)
# Inference time: 650.39 ms
# (1, 3, 416, 416)
# Inference time: 636.84 ms
# (1, 3, 416, 416)
# Inference time: 635.30 ms
# (1, 3, 416, 416)
# Inference time: 645.61 ms
# (1, 3, 416, 416)
# Inference time: 753.69 ms
# (1, 3, 416, 416)
# Inference time: 736.73 ms
# (1, 3, 416, 416)
# Inference time: 640.97 ms
# (1, 3, 416, 416)
# Inference time: 780.66 ms
# (1, 3, 416, 416)
# Inference time: 699.50 ms
# (1, 3, 416, 416)
# Inference time: 637.08 ms
# (1, 3, 416, 416)
# Inference time: 640.29 ms
# (1, 3, 416, 416)
# Inference time: 629.32 ms
# (1, 3, 416, 416)
# Inference time: 633.07 ms
# (1, 3, 416, 416)
# Inference time: 634.82 ms
# (1, 3, 416, 416)
# Inference time: 635.62 ms
# (1, 3, 416, 416)
# Inference time: 634.38 ms
# (1, 3, 416, 416)
# Inference time: 629.30 ms
# (1, 3, 416, 416)
# Inference time: 632.15 ms
# (1, 3, 416, 416)
# Inference time: 619.58 ms
# (1, 3, 416, 416)
# Inference time: 620.06 ms
# (1, 3, 416, 416)
# Inference time: 625.97 ms
# (1, 3, 416, 416)
# Inference time: 627.60 ms
# (1, 3, 416, 416)
# Inference time: 637.33 ms
# (1, 3, 416, 416)
# Inference time: 645.28 ms
# (1, 3, 416, 416)
# Inference time: 628.01 ms
# (1, 3, 416, 416)
# Inference time: 644.93 ms
# (1, 3, 416, 416)
# Inference time: 822.82 ms
# (1, 3, 416, 416)
# Inference time: 622.57 ms
# (1, 3, 416, 416)
# Inference time: 634.25 ms
# (1, 3, 416, 416)
# Inference time: 628.46 ms
# (1, 3, 416, 416)
# Inference time: 660.26 ms
# (1, 3, 416, 416)
# Inference time: 620.37 ms
# (1, 3, 416, 416)
# Inference time: 625.65 ms
# (1, 3, 416, 416)
# Inference time: 623.73 ms
# (1, 3, 416, 416)
# Inference time: 626.57 ms
# (1, 3, 416, 416)
# Inference time: 622.02 ms
# (1, 3, 416, 416)
# Inference time: 636.42 ms
# (1, 3, 416, 416)
# Inference time: 705.66 ms
# (1, 3, 416, 416)
# Inference time: 691.98 ms
# (1, 3, 416, 416)
# Inference time: 827.23 ms
# (1, 3, 416, 416)
# Inference time: 723.21 ms
# (1, 3, 416, 416)
# Inference time: 653.09 ms
# (1, 3, 416, 416)
# Inference time: 620.93 ms
# (1, 3, 416, 416)
# Inference time: 617.09 ms
# (1, 3, 416, 416)
# Inference time: 627.88 ms
# (1, 3, 416, 416)
# Inference time: 629.97 ms
# (1, 3, 416, 416)
# Inference time: 862.25 ms
# (1, 3, 416, 416)
# Inference time: 1086.19 ms
# (1, 3, 416, 416)
# Inference time: 631.01 ms
# (1, 3, 416, 416)
# Inference time: 631.20 ms
# (1, 3, 416, 416)
# Inference time: 633.89 ms
# (1, 3, 416, 416)
# Inference time: 633.79 ms
# (1, 3, 416, 416)
# Inference time: 628.51 ms
# (1, 3, 416, 416)
# Inference time: 626.74 ms
# (1, 3, 416, 416)
# Inference time: 632.53 ms
# (1, 3, 416, 416)
# Inference time: 670.93 ms
# (1, 3, 416, 416)
# Inference time: 654.01 ms
# (1, 3, 416, 416)
# Inference time: 651.11 ms
# (1, 3, 416, 416)
# Inference time: 663.31 ms
# (1, 3, 416, 416)
# Inference time: 666.89 ms
# (1, 3, 416, 416)
# Inference time: 661.81 ms
# (1, 3, 416, 416)
# Inference time: 667.76 ms
# (1, 3, 416, 416)
# Inference time: 909.38 ms
# (1, 3, 416, 416)
# Inference time: 960.48 ms
# (1, 3, 416, 416)
# Inference time: 796.70 ms
# (1, 3, 416, 416)
# Inference time: 653.28 ms
# (1, 3, 416, 416)
# Inference time: 891.95 ms
# (1, 3, 416, 416)
# Inference time: 720.03 ms
# (1, 3, 416, 416)
# Inference time: 664.66 ms
# (1, 3, 416, 416)
# Inference time: 663.66 ms
# (1, 3, 416, 416)
# Inference time: 676.07 ms
# (1, 3, 416, 416)
# Inference time: 662.67 ms
# (1, 3, 416, 416)
# Inference time: 645.01 ms
# (1, 3, 416, 416)
# Inference time: 676.82 ms
# (1, 3, 416, 416)
# Inference time: 677.46 ms
# (1, 3, 416, 416)
# Inference time: 639.67 ms
# (1, 3, 416, 416)
# Inference time: 619.73 ms
# (1, 3, 416, 416)
# Inference time: 628.93 ms
# (1, 3, 416, 416)
# Inference time: 622.18 ms
# (1, 3, 416, 416)
# Inference time: 616.18 ms
# (1, 3, 416, 416)
# Inference time: 624.99 ms
# (1, 3, 416, 416)
# Inference time: 685.51 ms
# (1, 3, 416, 416)
# Inference time: 663.45 ms
# (1, 3, 416, 416)
# Inference time: 620.45 ms
# (1, 3, 416, 416)
# Inference time: 668.35 ms
# (1, 3, 416, 416)
# Inference time: 620.15 ms
# (1, 3, 416, 416)
# Inference time: 611.53 ms
# (1, 3, 416, 416)
# Inference time: 792.66 ms
# (1, 3, 416, 416)
# Inference time: 663.70 ms
# (1, 3, 416, 416)
# Inference time: 614.79 ms
# (1, 3, 416, 416)
# Inference time: 624.76 ms
# (1, 3, 416, 416)
# Inference time: 618.73 ms
# (1, 3, 416, 416)
# Inference time: 613.28 ms
# (1, 3, 416, 416)
# Inference time: 617.22 ms
# (1, 3, 416, 416)
# Inference time: 605.84 ms
# (1, 3, 416, 416)
# Inference time: 630.60 ms
# (1, 3, 416, 416)
# Inference time: 614.42 ms
# (1, 3, 416, 416)
# Inference time: 612.58 ms
# (1, 3, 416, 416)
# Inference time: 633.02 ms
# (1, 3, 416, 416)
# Inference time: 616.76 ms
# (1, 3, 416, 416)
# Inference time: 621.26 ms
# (1, 3, 416, 416)
# Inference time: 618.70 ms
# (1, 3, 416, 416)
# Inference time: 615.71 ms
# (1, 3, 416, 416)
# Inference time: 617.76 ms
# (1, 3, 416, 416)
# Inference time: 688.98 ms
# (1, 3, 416, 416)
# Inference time: 616.60 ms
# (1, 3, 416, 416)
# Inference time: 614.31 ms
# (1, 3, 416, 416)
# Inference time: 609.07 ms
# (1, 3, 416, 416)
# Inference time: 646.76 ms
# (1, 3, 416, 416)
# Inference time: 815.84 ms
# (1, 3, 416, 416)
# Inference time: 615.91 ms
# (1, 3, 416, 416)
# Inference time: 621.96 ms
# (1, 3, 416, 416)
# Inference time: 617.66 ms
# (1, 3, 416, 416)
# Inference time: 616.92 ms
# (1, 3, 416, 416)
# Inference time: 628.48 ms
# (1, 3, 416, 416)
# Inference time: 618.41 ms
# (1, 3, 416, 416)
# Inference time: 607.73 ms
# (1, 3, 416, 416)
# Inference time: 615.88 ms
# (1, 3, 416, 416)
# Inference time: 607.26 ms
# (1, 3, 416, 416)
# Inference time: 613.20 ms
# (1, 3, 416, 416)
# Inference time: 622.87 ms
# (1, 3, 416, 416)
# Inference time: 618.77 ms
# (1, 3, 416, 416)
# Inference time: 617.46 ms
# (1, 3, 416, 416)
# Inference time: 610.54 ms
# (1, 3, 416, 416)
# Inference time: 617.72 ms
# (1, 3, 416, 416)
# Inference time: 632.13 ms
# (1, 3, 416, 416)
# Inference time: 610.34 ms
# (1, 3, 416, 416)
# Inference time: 626.88 ms
# (1, 3, 416, 416)
# Inference time: 614.28 ms
# (1, 3, 416, 416)
# Inference time: 619.35 ms
# (1, 3, 416, 416)
# Inference time: 610.85 ms
# (1, 3, 416, 416)
# Inference time: 606.89 ms
# (1, 3, 416, 416)
# Inference time: 609.78 ms
# (1, 3, 416, 416)
# Inference time: 717.16 ms
# (1, 3, 416, 416)
# Inference time: 727.32 ms
# (1, 3, 416, 416)
# Inference time: 616.19 ms
# (1, 3, 416, 416)
# Inference time: 620.81 ms
# (1, 3, 416, 416)
# Inference time: 614.11 ms
# (1, 3, 416, 416)
# Inference time: 622.11 ms
# (1, 3, 416, 416)
# Inference time: 622.21 ms
# (1, 3, 416, 416)
# Inference time: 625.44 ms
# (1, 3, 416, 416)
# Inference time: 632.13 ms
# (1, 3, 416, 416)
# Inference time: 611.97 ms
# (1, 3, 416, 416)
# Inference time: 611.71 ms
# (1, 3, 416, 416)
# Inference time: 616.80 ms
# (1, 3, 416, 416)
# Inference time: 633.41 ms
# (1, 3, 416, 416)
# Inference time: 614.32 ms
# (1, 3, 416, 416)
# Inference time: 617.92 ms
# (1, 3, 416, 416)
# Inference time: 615.65 ms
# (1, 3, 416, 416)
# Inference time: 612.62 ms
# (1, 3, 416, 416)
# Inference time: 609.73 ms
# (1, 3, 416, 416)
# Inference time: 651.66 ms
# (1, 3, 416, 416)
# Inference time: 607.17 ms
# (1, 3, 416, 416)
# Inference time: 625.14 ms
# (1, 3, 416, 416)
# Inference time: 640.90 ms
# (1, 3, 416, 416)
# Inference time: 620.85 ms
# (1, 3, 416, 416)
# Inference time: 604.88 ms
# (1, 3, 416, 416)
# Inference time: 618.34 ms
# (1, 3, 416, 416)
# Inference time: 618.72 ms
# (1, 3, 416, 416)
# Inference time: 688.48 ms
# (1, 3, 416, 416)
# Inference time: 756.35 ms
# (1, 3, 416, 416)
# Inference time: 812.74 ms
# (1, 3, 416, 416)
# Inference time: 651.33 ms
# (1, 3, 416, 416)
# Inference time: 681.33 ms
# (1, 3, 416, 416)
# Inference time: 668.30 ms
# (1, 3, 416, 416)
# Inference time: 653.99 ms
# (1, 3, 416, 416)
# Inference time: 677.94 ms
# (1, 3, 416, 416)
# Inference time: 630.51 ms
# (1, 3, 416, 416)
# Inference time: 669.41 ms
# (1, 3, 416, 416)
# Inference time: 663.20 ms
# (1, 3, 416, 416)
# Inference time: 612.46 ms
# (1, 3, 416, 416)
# Inference time: 655.18 ms
# (1, 3, 416, 416)
# Inference time: 609.95 ms
# (1, 3, 416, 416)
# Inference time: 616.72 ms
# (1, 3, 416, 416)
# Inference time: 614.05 ms
# (1, 3, 416, 416)
# Inference time: 626.06 ms
# (1, 3, 416, 416)
# Inference time: 620.20 ms
# (1, 3, 416, 416)
# Inference time: 616.02 ms
# (1, 3, 416, 416)
# Inference time: 627.16 ms
# (1, 3, 416, 416)
# Inference time: 617.33 ms
# (1, 3, 416, 416)
# Inference time: 637.29 ms
# (1, 3, 416, 416)
# Inference time: 611.30 ms
# (1, 3, 416, 416)
# Inference time: 607.53 ms
# (1, 3, 416, 416)
# Inference time: 620.78 ms
# (1, 3, 416, 416)
# Inference time: 607.52 ms
# (1, 3, 416, 416)
# Inference time: 605.11 ms
# (1, 3, 416, 416)
# Inference time: 650.06 ms
# (1, 3, 416, 416)
# Inference time: 810.29 ms
# (1, 3, 416, 416)
# Inference time: 615.36 ms
# (1, 3, 416, 416)
# Inference time: 616.99 ms
# (1, 3, 416, 416)
# Inference time: 620.88 ms
# (1, 3, 416, 416)
# Inference time: 627.65 ms
# (1, 3, 416, 416)
# Inference time: 611.34 ms
# (1, 3, 416, 416)
# Inference time: 621.89 ms
# (1, 3, 416, 416)
# Inference time: 618.10 ms
# (1, 3, 416, 416)
# Inference time: 619.15 ms
# (1, 3, 416, 416)
# Inference time: 620.82 ms
# (1, 3, 416, 416)
# Inference time: 626.34 ms
# (1, 3, 416, 416)
# Inference time: 622.61 ms
# (1, 3, 416, 416)
# Inference time: 616.74 ms
# (1, 3, 416, 416)
# Inference time: 677.46 ms
# (1, 3, 416, 416)
# Inference time: 785.92 ms
# (1, 3, 416, 416)
# Inference time: 605.85 ms
# (1, 3, 416, 416)
# Inference time: 608.09 ms
# (1, 3, 416, 416)
# Inference time: 607.22 ms
# (1, 3, 416, 416)
# Inference time: 603.45 ms
# (1, 3, 416, 416)
# Inference time: 608.26 ms
# (1, 3, 416, 416)
# Inference time: 610.84 ms
# (1, 3, 416, 416)
# Inference time: 613.92 ms
# (1, 3, 416, 416)
# Inference time: 636.63 ms
# (1, 3, 416, 416)
# Inference time: 610.12 ms
# (1, 3, 416, 416)
# Inference time: 630.87 ms
# (1, 3, 416, 416)
# Inference time: 613.09 ms
# (1, 3, 416, 416)
# Inference time: 612.56 ms
# (1, 3, 416, 416)
# Inference time: 616.96 ms
# (1, 3, 416, 416)
# Inference time: 608.49 ms
# (1, 3, 416, 416)
# Inference time: 618.90 ms
# (1, 3, 416, 416)
# Inference time: 671.26 ms
# (1, 3, 416, 416)
# Inference time: 635.67 ms
# (1, 3, 416, 416)
# Inference time: 664.12 ms
# (1, 3, 416, 416)
# Inference time: 628.21 ms
# (1, 3, 416, 416)
# Inference time: 624.66 ms
# (1, 3, 416, 416)
# Inference time: 641.58 ms
# (1, 3, 416, 416)
# Inference time: 644.60 ms
# (1, 3, 416, 416)
# Inference time: 630.21 ms
# (1, 3, 416, 416)
# Inference time: 656.83 ms
# (1, 3, 416, 416)
# Inference time: 640.94 ms
# (1, 3, 416, 416)
# Inference time: 628.17 ms
# (1, 3, 416, 416)
# Inference time: 729.80 ms
# (1, 3, 416, 416)
# Inference time: 760.11 ms
# (1, 3, 416, 416)
# Inference time: 640.69 ms
# (1, 3, 416, 416)
# Inference time: 673.68 ms
# (1, 3, 416, 416)
# Inference time: 658.02 ms
# (1, 3, 416, 416)
# Inference time: 633.62 ms
# (1, 3, 416, 416)
# Inference time: 631.99 ms
# (1, 3, 416, 416)
# Inference time: 633.85 ms
# (1, 3, 416, 416)
# Inference time: 661.40 ms
# (1, 3, 416, 416)
# Inference time: 635.26 ms
# (1, 3, 416, 416)
# Inference time: 650.30 ms
# (1, 3, 416, 416)
# Inference time: 650.83 ms
# (1, 3, 416, 416)
# Inference time: 647.13 ms
# (1, 3, 416, 416)
# Inference time: 639.45 ms
# (1, 3, 416, 416)
# Inference time: 799.93 ms
# (1, 3, 416, 416)
# Inference time: 805.05 ms
# (1, 3, 416, 416)
# Inference time: 673.52 ms
# (1, 3, 416, 416)
# Inference time: 633.06 ms
# (1, 3, 416, 416)
# Inference time: 697.13 ms
# (1, 3, 416, 416)
# Inference time: 669.18 ms
# (1, 3, 416, 416)
# Inference time: 661.64 ms
# (1, 3, 416, 416)
# Inference time: 642.02 ms
# (1, 3, 416, 416)
# Inference time: 630.99 ms
# (1, 3, 416, 416)
# Inference time: 641.79 ms
# (1, 3, 416, 416)
# Inference time: 643.09 ms
# (1, 3, 416, 416)
# Inference time: 642.37 ms
# (1, 3, 416, 416)
# Inference time: 652.66 ms
# (1, 3, 416, 416)
# Inference time: 643.20 ms
# (1, 3, 416, 416)
# Inference time: 627.07 ms
# (1, 3, 416, 416)
# Inference time: 661.67 ms
# (1, 3, 416, 416)
# Inference time: 633.42 ms
# (1, 3, 416, 416)
# Inference time: 657.91 ms
# (1, 3, 416, 416)
# Inference time: 651.63 ms
# (1, 3, 416, 416)
# Inference time: 820.60 ms
# (1, 3, 416, 416)
# Inference time: 644.73 ms
# (1, 3, 416, 416)
# Inference time: 639.26 ms
# (1, 3, 416, 416)
# Inference time: 635.11 ms
# (1, 3, 416, 416)
# Inference time: 640.71 ms
# (1, 3, 416, 416)
# Inference time: 709.70 ms
# (1, 3, 416, 416)
# Inference time: 631.51 ms
# (1, 3, 416, 416)
# Inference time: 647.22 ms
# (1, 3, 416, 416)
# Inference time: 630.53 ms
# (1, 3, 416, 416)
# Inference time: 644.85 ms
# (1, 3, 416, 416)
# Inference time: 633.76 ms
# (1, 3, 416, 416)
# Inference time: 631.71 ms
# (1, 3, 416, 416)
# Inference time: 662.01 ms
# (1, 3, 416, 416)
# Inference time: 653.58 ms
# (1, 3, 416, 416)
# Inference time: 685.99 ms
# (1, 3, 416, 416)
# Inference time: 630.26 ms
# (1, 3, 416, 416)
# Inference time: 645.06 ms
# (1, 3, 416, 416)
# Inference time: 626.68 ms
# (1, 3, 416, 416)
# Inference time: 637.17 ms
# (1, 3, 416, 416)
# Inference time: 640.16 ms
# (1, 3, 416, 416)
# Inference time: 641.71 ms
# (1, 3, 416, 416)
# Inference time: 649.70 ms
# (1, 3, 416, 416)
# Inference time: 655.43 ms
# (1, 3, 416, 416)
# Inference time: 640.04 ms
# (1, 3, 416, 416)
# Inference time: 637.17 ms
# (1, 3, 416, 416)
# Inference time: 641.74 ms
# (1, 3, 416, 416)
# Inference time: 635.61 ms
# (1, 3, 416, 416)
# Inference time: 890.76 ms
# (1, 3, 416, 416)
# Inference time: 637.15 ms
# (1, 3, 416, 416)
# Inference time: 640.49 ms
# (1, 3, 416, 416)
# Inference time: 660.12 ms
# (1, 3, 416, 416)
# Inference time: 653.78 ms
# (1, 3, 416, 416)
# Inference time: 636.48 ms
# (1, 3, 416, 416)
# Inference time: 751.66 ms
# (1, 3, 416, 416)
# Inference time: 644.79 ms
# (1, 3, 416, 416)
# Inference time: 654.98 ms
# (1, 3, 416, 416)
# Inference time: 641.12 ms
# (1, 3, 416, 416)
# Inference time: 654.42 ms
# (1, 3, 416, 416)
# Inference time: 676.31 ms
# (1, 3, 416, 416)
# Inference time: 649.86 ms
# (1, 3, 416, 416)
# Inference time: 729.28 ms
# (1, 3, 416, 416)
# Inference time: 828.36 ms
# (1, 3, 416, 416)
# Inference time: 662.57 ms
# (1, 3, 416, 416)
# Inference time: 642.06 ms
# (1, 3, 416, 416)
# Inference time: 644.10 ms
# (1, 3, 416, 416)
# Inference time: 653.20 ms
# (1, 3, 416, 416)
# Inference time: 632.34 ms
# (1, 3, 416, 416)
# Inference time: 641.33 ms
# (1, 3, 416, 416)
# Inference time: 649.20 ms
# (1, 3, 416, 416)
# Inference time: 657.52 ms
# (1, 3, 416, 416)
# Inference time: 666.35 ms
# (1, 3, 416, 416)
# Inference time: 643.33 ms
# (1, 3, 416, 416)
# Inference time: 644.51 ms
# (1, 3, 416, 416)
# Inference time: 671.83 ms
# (1, 3, 416, 416)
# Inference time: 633.11 ms
# (1, 3, 416, 416)
# Inference time: 643.88 ms
# (1, 3, 416, 416)
# Inference time: 653.15 ms
# (1, 3, 416, 416)
# Inference time: 639.83 ms
# (1, 3, 416, 416)
# Inference time: 688.89 ms
# (1, 3, 416, 416)
# Inference time: 644.21 ms
# (1, 3, 416, 416)
# Inference time: 646.16 ms
# (1, 3, 416, 416)
# Inference time: 777.18 ms
# (1, 3, 416, 416)
# Inference time: 736.54 ms
# (1, 3, 416, 416)
# Inference time: 675.39 ms
# (1, 3, 416, 416)
# Inference time: 653.35 ms
# (1, 3, 416, 416)
# Inference time: 642.90 ms
# (1, 3, 416, 416)
# Inference time: 643.18 ms
# (1, 3, 416, 416)
# Inference time: 643.69 ms
# (1, 3, 416, 416)
# Inference time: 641.42 ms
# (1, 3, 416, 416)
# Inference time: 779.69 ms
# (1, 3, 416, 416)
# Inference time: 657.67 ms
# (1, 3, 416, 416)
# Inference time: 647.38 ms
# (1, 3, 416, 416)
# Inference time: 692.63 ms
# (1, 3, 416, 416)
# Inference time: 652.59 ms
# (1, 3, 416, 416)
# Inference time: 641.20 ms
# (1, 3, 416, 416)
# Inference time: 630.06 ms
# (1, 3, 416, 416)
# Inference time: 637.65 ms
# (1, 3, 416, 416)
# Inference time: 643.20 ms
# (1, 3, 416, 416)
# Inference time: 649.42 ms
# (1, 3, 416, 416)
# Inference time: 644.84 ms
# (1, 3, 416, 416)
# Inference time: 637.44 ms
# (1, 3, 416, 416)
# Inference time: 634.72 ms
# (1, 3, 416, 416)
# Inference time: 784.07 ms
# (1, 3, 416, 416)
# Inference time: 716.94 ms
# (1, 3, 416, 416)
# Inference time: 651.51 ms
# (1, 3, 416, 416)
# Inference time: 649.23 ms
# (1, 3, 416, 416)
# Inference time: 654.04 ms
# (1, 3, 416, 416)
# Inference time: 642.46 ms
# (1, 3, 416, 416)
# Inference time: 656.37 ms
# (1, 3, 416, 416)
# Inference time: 653.46 ms
# (1, 3, 416, 416)
# Inference time: 656.78 ms
# (1, 3, 416, 416)
# Inference time: 646.55 ms
# (1, 3, 416, 416)
# Inference time: 653.12 ms
# (1, 3, 416, 416)
# Inference time: 667.78 ms
# (1, 3, 416, 416)
# Inference time: 621.71 ms
# (1, 3, 416, 416)
# Inference time: 611.17 ms
# (1, 3, 416, 416)
# Inference time: 611.30 ms
# (1, 3, 416, 416)
# Inference time: 678.89 ms
# (1, 3, 416, 416)
# Inference time: 660.81 ms
# (1, 3, 416, 416)
# Inference time: 621.08 ms
# (1, 3, 416, 416)
# Inference time: 640.86 ms
# (1, 3, 416, 416)
# Inference time: 635.68 ms
# (1, 3, 416, 416)
# Inference time: 626.94 ms
# (1, 3, 416, 416)
# Inference time: 743.66 ms
# (1, 3, 416, 416)
# Inference time: 694.56 ms
# (1, 3, 416, 416)
# Inference time: 615.41 ms
# (1, 3, 416, 416)
# Inference time: 630.49 ms
# (1, 3, 416, 416)
# Inference time: 621.33 ms
# (1, 3, 416, 416)
# Inference time: 623.57 ms
# (1, 3, 416, 416)
# Inference time: 610.42 ms
# (1, 3, 416, 416)
# Inference time: 608.57 ms
# (1, 3, 416, 416)
# Inference time: 619.92 ms
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a151110bb680> in <module>
#       9 while cap.isOpened():
#      10     ret, frame = cap.read()
# ---> 11     frame = process(frame)
#      12     writer.write(frame)
#      13     cv2.imshow('Lane Detection Video', frame)
#
# <ipython-input-3-b01ccc4f430f> in process(image)
#      30
#      31 def process(image):
# ---> 32     (H, W) = image.shape[:2]
#      33
#      34     # Get the output layer names:
#
# AttributeError: 'NoneType' object has no attribute 'shape'
