# %%
import matplotlib.pylab as plt

# %%
import cv2

# %%
import numpy as np

# %%
image = cv2.imread('Image.png')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
print(image.shape)
# Out:
# (764, 1327, 3)

# %%
print(image.shape)
height = image.shape[0]
width = image.shape[1]
# Out:
# (764, 1327, 3)

# %%
image = cv2.imread('Image.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print(image.shape)
height = image.shape[0]
width = image.shape[1]
# Out:
# (764, 1327, 3)

# %%
plt.imshow(image)

# %%
region_of_interest_vertices = [
    (0,height),
    (width/2, height/2),
    (width, height)]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img,mask)
    return masked_image
 
masked_image = region_of_interest(image, 
                                  np.array([region_of_interest_vertices], np.int32))    
    
plt.imshow(masked_image)
plt.show()

# %%
region_of_interest_vertices = [
    (0,height),
    (width/2, height/1.5),
    (width, height)]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img,mask)
    return masked_image
 
masked_image = region_of_interest(image, 
                                  np.array([region_of_interest_vertices], np.int32))    
    
plt.imshow(masked_image)
plt.show()

# %%
region_of_interest_vertices = [
    (0,height),
    (width/2, height/3),
    (width, height)]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img,mask)
    return masked_image
 
masked_image = region_of_interest(image, 
                                  np.array([region_of_interest_vertices], np.int32))    
    
plt.imshow(masked_image)
plt.show()

# %%
region_of_interest_vertices = [
    (0,height),
    (width/2, height/2.5),
    (width, height)]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img,mask)
    return masked_image
 
masked_image = region_of_interest(image, 
                                  np.array([region_of_interest_vertices], np.int32))    
    
plt.imshow(masked_image)
plt.show()

# %%
region_of_interest_vertices = [
    (0,height),
    (width/2, height/2.3),
    (width, height)]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img,mask)
    return masked_image
 
masked_image = region_of_interest(image, 
                                  np.array([region_of_interest_vertices], np.int32))    
    
plt.imshow(masked_image)
plt.show()

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image, #numpy array on which text is written
     "Masked Image- Limits the visible area to allow for easier lane identification", #text
     position, #position at which writing has to start
     cv2.FONT_HERSHEY_SIMPLEX, #font family
     1, #font size
     (209, 80, 0, 255), #font color
     3) #font stroke
cv2.imwrite('Masked.png', image)

plt.imshow(masked_image)
plt.show()

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image, #numpy array on which text is written
     "Masked Image- Limits the visible area to allow for easier lane identification", #text
     position, #position at which writing has to start
     cv2.FONT_HERSHEY_SIMPLEX, #font family
     1, #font size
     ('white'), #font color
     3) #font stroke
cv2.imwrite('Masked.png', image)

plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-63-6a58561b7681> in <module>
#       5
#       6 position = (10,50)
# ----> 7 cv2.putText(
#       8      image, #numpy array on which text is written
#       9      "Masked Image- Limits the visible area to allow for easier lane identification", #text
#
# error: OpenCV(4.5.3) :-1: error: (-5:Bad argument) in function 'putText'
# > Overload resolution failed:
# >  - Scalar value for argument 'color' is longer than 4
# >  - Scalar value for argument 'color' is longer than 4

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image,
     "Masked Image- Limits the visible area to allow for easier lane identification",
     position, 
     cv2.FONT_HERSHEY_SIMPLEX, 
     2, 
     (255, 255, 0, 255), 
     3)
cv2.imwrite('Masked.png', image)

plt.imshow(image)
plt.show()

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image,
     "Masked Image- Limits the visible area to allow for easier lane identification",
     position, 
     cv2.FONT_HERSHEY_SIMPLEX, 
     1.3, 
     (255, 255, 0, 255), 
     3)
cv2.imwrite('Masked.png', image)

plt.imshow(image)
plt.show()

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image,
     "Masked Image- Limits the visible area to allow for easier lane identification",
     position, 
     cv2.FONT_HERSHEY_SIMPLEX, 
     1.1, 
     (255, 255, 0, 255), 
     3)
cv2.imwrite('Masked.png', image)

plt.imshow(image)
plt.show()

# %%
import numpy as np
import cv2

image = cv2.imread('Image2.jpg',cv2.IMREAD_UNCHANGED)

position = (10,50)
cv2.putText(
     image,
     "Masked Image- Limits the visible area to allow for easier lane identification",
     position, 
     cv2.FONT_HERSHEY_SIMPLEX, 
     1.05, 
     (255, 255, 255, 255), 
     3)
cv2.imwrite('Masked.png', image)

plt.imshow(image)
plt.show()
