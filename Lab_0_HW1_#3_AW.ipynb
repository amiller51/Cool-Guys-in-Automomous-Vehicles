# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\acewa\Downloads\Lab0_data.xlsx')

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
import numpy
import matplotlib.pyplot as plt

# %%
plt.plot(df['time_sec'], df['VehicleSpeed_mph'])
plt.xlabel('Seconds')
plt.ylabel('mph')
plt.title('Speed vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['EngineSpeed_rpm'])
plt.xlabel('Seconds')
plt.ylabel('rpm')
plt.title('Rotational Speed vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['EngineTorque'])
plt.xlabel('Seconds')
plt.ylabel('Torque')
plt.title('Engine Torque vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['AccelPedalPos'])
plt.xlabel('Seconds')
plt.ylabel('Position')
plt.title('Pedal Position vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['BrakePedalPos'])
plt.xlabel('Seconds')
plt.ylabel('Position')
plt.title('Brake Pedal Position vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['TurnSignal'])
plt.xlabel('Seconds')
plt.ylabel('Position')
plt.title('TurnSignal vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['Latitude_deg'])
plt.xlabel('Seconds')
plt.ylabel('Deg')
plt.title('Latitude (deg) vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['Longitude_deg'])
plt.xlabel('Seconds')
plt.ylabel('Deg')
plt.title('Longitude (deg) vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['Altitude'])
plt.xlabel('Seconds')
plt.ylabel('Distance')
plt.title('Altitude vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['Distance'])
plt.xlabel('Seconds')
plt.ylabel('Distance')
plt.title('Distance vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['SteerAngle'])
plt.xlabel('Seconds')
plt.ylabel('Deg')
plt.title('SteerAngle vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['TransmissionGear'])
plt.xlabel('Seconds')
plt.ylabel('Gear')
plt.title('Transmission Gear vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['SPaT_signal'])
plt.xlabel('Seconds')
plt.ylabel('Signal')
plt.title('SPaT Signal vs Time')
plt.grid()

# %%
plt.plot(df['time_sec'], df['SPaT_dist'])
plt.xlabel('Seconds')
plt.ylabel('Distance')
plt.title('SPaT Distance vs Time')
plt.grid()
