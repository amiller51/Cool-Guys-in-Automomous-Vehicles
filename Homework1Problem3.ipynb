# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\hunte\Documents\Python\Lab0_data (1).xlsx')

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["time_sec"], df["VehicleSpeed_mph"], color='red')
plt.grid()
plt.ylabel("Vehicle Speed [mph]")
plt.xlabel("Time [s]")
plt.title("Vehicle Speed vs Time")
# Out:
# Text(0.5, 1.0, 'Vehicle Speed vs Time')

# %%
plt.plot(df["time_sec"], df["EngineSpeed_rpm"], color='cyan')
plt.grid()
plt.ylabel("Engine Speed [rpm]")
plt.xlabel("Time [s]")
plt.title("Engine Speed vs Time")
# Out:
# Text(0.5, 1.0, 'Engine Speed vs Time')

# %%
plt.plot(df["time_sec"], df["EngineTorque"], color='pink')
plt.grid()
plt.ylabel("Engine Torque")
plt.xlabel("Time [s]")
plt.title("Engine Torque vs Time")
# Out:
# Text(0.5, 1.0, 'Engine Torque vs Time')

# %%
plt.plot(df["time_sec"], df["AccelPedalPos"], color='green')
plt.grid()
plt.ylabel("Acceleration Pedal Position")
plt.xlabel("Time [s]")
plt.title("Acceleration Pedal Position vs Time")
# Out:
# Text(0.5, 1.0, 'Acceleration Pedal Position vs Time')

# %%
plt.plot(df["time_sec"], df["BrakePedalPos"], color='chartreuse')
plt.grid()
plt.ylabel("Brake Pedal Position")
plt.xlabel("Time [s]")
plt.title("Brake Pedal Position vs Time")
# Out:
# Text(0.5, 1.0, 'Brake Pedal Position vs Time')

# %%
plt.plot(df["time_sec"], df["TurnSignal"], color='brown')
plt.grid()
plt.ylabel("Turn Signal")
plt.xlabel("Time [s]")
plt.title("Turn Signal vs Time")
# Out:
# Text(0.5, 1.0, 'Turn Signal vs Time')

# %%
plt.plot(df["time_sec"], df["Longitude_deg"], color='yellow')
plt.grid()
plt.ylabel("Longitude")
plt.xlabel("Time [s]")
plt.title("Longitude vs Time")
# Out:
# Text(0.5, 1.0, 'Longitude vs Time')

# %%
plt.plot(df["time_sec"], df["Altitude"], color='purple')
plt.grid()
plt.ylabel("Altitude [deg]")
plt.xlabel("Time [s]")
plt.title("Altitude vs Time")
# Out:
# Text(0.5, 1.0, 'Altitude vs Time')

# %%
plt.plot(df["time_sec"], df["Distance"], color='blue')
plt.grid()
plt.ylabel("Distance [deg]")
plt.xlabel("Time [s]")
plt.title("Distance vs Time")
# Out:
# Text(0.5, 1.0, 'Distance vs Time')

# %%
plt.plot(df["time_sec"], df["SteerAngle"], color='green')
plt.grid()
plt.ylabel("Steering Angle")
plt.xlabel("Time [s]")
plt.title("Steering Angle vs Time")
# Out:
# Text(0.5, 1.0, 'Steering Angle vs Time')

# %%
plt.plot(df["time_sec"], df["TransmissionGear"], color='red')
plt.grid()
plt.ylabel("Transmission Gear")
plt.xlabel("Time [s]")
plt.title("Transmission Gear vs Time")
# Out:
# Text(0.5, 1.0, 'Transmission Gear vs Time')

# %%
#forgot latitude

# %%
plt.plot(df["time_sec"], df["Latitude_deg"], color='green')
plt.grid()
plt.ylabel("Latitude [deg]")
plt.xlabel("Time [s]")
plt.title("Latitude vs Time")
# Out:
# Text(0.5, 1.0, 'Latitude vs Time')
