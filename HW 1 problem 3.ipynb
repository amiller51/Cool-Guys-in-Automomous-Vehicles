# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Collin\Desktop\Auto Vehicles\Lab0_data.xlsx")

# %%
#import plotting packages

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
#print xlsx file to verify succesful import

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
#plot each column vs time

# %%
plt.plot(df["time_sec"], df["VehicleSpeed_mph"], color='green')
plt.grid()
plt.title("Vehicle Speed vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Vehicle Speed (mph)")
# Out:
# Text(0, 0.5, 'Vehicle Speed (mph)')

# %%
plt.plot(df["time_sec"], df["EngineSpeed_rpm"], color='orange')
plt.grid()
plt.title("Engine Speed vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Engine Speed (rpm)")
# Out:
# Text(0, 0.5, 'Engine Speed (rpm)')

# %%
plt.plot(df["time_sec"], df["EngineTorque"], color='blue')
plt.grid()
plt.title("Engine Torque vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Engine Torque")
# Out:
# Text(0, 0.5, 'Engine Torque')

# %%
plt.plot(df["time_sec"], df["AccelPedalPos"], color='brown')
plt.grid()
plt.title("Acceleration Pedal Position vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Acceleration Pedal Position")
# Out:
# Text(0, 0.5, 'Acceleration Pedal Position')

# %%
plt.plot(df["time_sec"], df["BrakePedalPos"], color='red')
plt.grid()
plt.title("Brake Pedal Position vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Brake Pedal Position")
# Out:
# Text(0, 0.5, 'Brake Pedal Position')

# %%
plt.plot(df["time_sec"], df["TurnSignal"], color='black')
plt.grid()
plt.title("Turn Signal vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Turn Signal")
# Out:
# Text(0, 0.5, 'Turn Signal')

# %%
plt.plot(df["time_sec"], df["Latitude_deg"], color='pink')
plt.grid()
plt.title("Latitude vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Latitude (deg)")
# Out:
# Text(0, 0.5, 'Latitude (deg)')

# %%
plt.plot(df["time_sec"], df["Longitude_deg"], color='purple')
plt.grid()
plt.title("Longitude vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Longitude (deg)")
# Out:
# Text(0, 0.5, 'Longitude (deg)')

# %%
plt.plot(df["time_sec"], df["Altitude"], color='yellow')
plt.grid()
plt.title("Altitude vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Altitude (deg)")
# Out:
# Text(0, 0.5, 'Altitude (deg)')

# %%
plt.plot(df["time_sec"], df["Distance"], color='cyan')
plt.grid()
plt.title("Distance vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Distance (deg)")
# Out:
# Text(0, 0.5, 'Distance (deg)')

# %%
plt.plot(df["time_sec"], df["SteerAngle"], color='magenta')
plt.grid()
plt.title("Steering Angle vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Steering Angle")
# Out:
# Text(0, 0.5, 'Steering Angle')

# %%
plt.plot(df["time_sec"], df["TransmissionGear"], color='dodgerblue')
plt.grid()
plt.title("Transmission Gear vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Transmission Gear")
# Out:
# Text(0, 0.5, 'Transmission Gear')
